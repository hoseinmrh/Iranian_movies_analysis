# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset.csv")

# %%
df
# Out:
#                                                    Link  \
# 0     https://www.imvbox.com/watch-persian-movie-ira...
# 1     https://www.imvbox.com/watch-persian-movie-ira...
# 2     https://www.imvbox.com/watch-persian-movie-ira...
# 3     https://www.imvbox.com/watch-persian-movie-ira...
# 4     https://www.imvbox.com/watch-persian-movie-ira...
# ...                                                 ...
# 1432  https://www.imvbox.com/watch-persian-movie-ira...
# 1433  https://www.imvbox.com/watch-persian-movie-ira...
# 1434  https://www.imvbox.com/watch-persian-movie-ira...
# 1435  https://www.imvbox.com/watch-persian-movie-ira...
# 1436  https://www.imvbox.com/watch-persian-movie-ira...
#
#                       EN_title       PENGLISH_title   PERSIAN_title  \
# 0            Local Anaesthetic     Bi Hessie Mozeie    بی‌حسی موضعی
# 1                  Disturbance            Ashoftegi        آشفته گی
# 2                    Highlight              Haylayt         هایلایت
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1437 entries, 0 to 1436
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Link            1437 non-null   object
#  1   EN_title        1437 non-null   object
#  2   PENGLISH_title  1432 non-null   object
#  3   PERSIAN_title   1436 non-null   object
#  4   Content_1       1076 non-null   object
#  5   Content_2       1231 non-null   object
#  6   Score           1437 non-null   float64
#  7   Year            1437 non-null   int64
#  8   Genre           1437 non-null   object
#  9   Time            1429 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 112.4+ KB

# %%
df.Time
# Out:
# 0        73
# 1        78
# 2        77
# 3        79
# 4        85
#        ...
# 1432    100
# 1433     19
# 1434     87
# 1435     89
# 1436     89
# Name: Time, Length: 1437, dtype: object

# %% [markdown]
# We can see that the time cloumn has some null values and also its type is object! Where it should be int. So we have to fix this

# %%
df.dropna(subset=['Time'], inplace=True) #Drop null values

# %%
df.info() #Now we can see we have no null values but now we need to change its type to int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1429 entries, 0 to 1436
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Link            1429 non-null   object
#  1   EN_title        1429 non-null   object
#  2   PENGLISH_title  1424 non-null   object
#  3   PERSIAN_title   1428 non-null   object
#  4   Content_1       1071 non-null   object
#  5   Content_2       1227 non-null   object
#  6   Score           1429 non-null   float64
#  7   Year            1429 non-null   int64
#  8   Genre           1429 non-null   object
#  9   Time            1429 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 122.8+ KB

# %%
df["Time"] = pd.to_numeric(df["Time"], errors='coerce')

# %%
df.dtypes
# Out:
# Link               object
# EN_title           object
# PENGLISH_title     object
# PERSIAN_title      object
# Content_1          object
# Content_2          object
# Score             float64
# Year                int64
# Genre              object
# Time              float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1429 entries, 0 to 1436
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Link            1429 non-null   object
#  1   EN_title        1429 non-null   object
#  2   PENGLISH_title  1424 non-null   object
#  3   PERSIAN_title   1428 non-null   object
#  4   Content_1       1071 non-null   object
#  5   Content_2       1227 non-null   object
#  6   Score           1429 non-null   float64
#  7   Year            1429 non-null   int64
#  8   Genre           1429 non-null   object
#  9   Time            1427 non-null   float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 122.8+ KB

# %%
df.dropna(subset=['Time'], inplace=True) #We drop null values again

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1427 entries, 0 to 1436
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Link            1427 non-null   object
#  1   EN_title        1427 non-null   object
#  2   PENGLISH_title  1422 non-null   object
#  3   PERSIAN_title   1426 non-null   object
#  4   Content_1       1070 non-null   object
#  5   Content_2       1226 non-null   object
#  6   Score           1427 non-null   float64
#  7   Year            1427 non-null   int64
#  8   Genre           1427 non-null   object
#  9   Time            1427 non-null   float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 122.6+ KB

# %% [markdown]
# Now we have 1427 movies with EN_title, score, year, genre and time

# %%
df #Let's take a look at dataframe
# Out:
#                                                    Link  \
# 0     https://www.imvbox.com/watch-persian-movie-ira...
# 1     https://www.imvbox.com/watch-persian-movie-ira...
# 2     https://www.imvbox.com/watch-persian-movie-ira...
# 3     https://www.imvbox.com/watch-persian-movie-ira...
# 4     https://www.imvbox.com/watch-persian-movie-ira...
# ...                                                 ...
# 1432  https://www.imvbox.com/watch-persian-movie-ira...
# 1433  https://www.imvbox.com/watch-persian-movie-ira...
# 1434  https://www.imvbox.com/watch-persian-movie-ira...
# 1435  https://www.imvbox.com/watch-persian-movie-ira...
# 1436  https://www.imvbox.com/watch-persian-movie-ira...
#
#                       EN_title       PENGLISH_title   PERSIAN_title  \
# 0            Local Anaesthetic     Bi Hessie Mozeie    بی‌حسی موضعی
# 1                  Disturbance            Ashoftegi        آشفته گی
# 2                    Highlight              Haylayt         هایلایت
# ...

# %%
df.describe()
# Out:
#              Score         Year         Time
# count  1427.000000  1427.000000  1427.000000
# mean      6.528942  2007.177295    86.166783
# std       1.562071     9.347512    19.854525
# min       0.000000  1968.000000     7.000000
# 25%       5.400000  2001.000000    81.000000
# 50%       6.800000  2010.000000    90.000000
# 75%       8.000000  2015.000000    96.000000
# max      10.000000  2020.000000   178.000000

# %% [markdown]
# Hear we can see the information about our numeric columns. The avarage score of a movie is around 6.5 and we can see that we have movies from year 1968 to 2020. The time column is intresting too. The avarage time of movies is about 86 minutes but the shortest movies were only 7 minutes and also the longest on is 178 minutes - near 3 hours - .

# %%
shortest_movies = df[df['Time'] == 7]
shortest_movies
# Out:
#                                                    Link    EN_title  \
# 659   https://www.imvbox.com/watch-persian-movie-ira...  Burnt City
# 1095  https://www.imvbox.com/watch-persian-movie-ira...    The Star
#
#       PENGLISH_title PERSIAN_title Content_1  \
# 659   Shahre Sukhteh     شهر سوخته       NaN
# 1095         Setareh         ستاره       NaN
#
#                                               Content_2  Score  Year  \
# 659   Soudabeh Moradian's short documentary is an ex...    7.0  2012
# 1095  The musical animation 'The Star' tells the sto...    6.2  2000
#
#              Genre  Time
# 659   Experimental   7.0
# 1095         Drama   7.0
